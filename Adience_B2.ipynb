# %%
import os
import numpy as np
import pandas as pd

labels = [i for i in os.listdir('/content/drive/MyDrive/Adience_Processed')]
len(labels)
# Out:
# 17058

# %%
age = ['_'.join(i.split("_")[-3:-1]) for i in labels]
print(len(age))
print(set(age))
print(len(set(age)))
# Out:
# 17058
# {'45_45', '29_29', '32_32', '57_57', '46_46', '42_42', '22_22', '34_34', '36_36', '48_53', '58_58', '25_32', '8_23', '8_12', '55_55', '60_100', '0_2', '27_32', '56_56', '2_2', '4_6', '3_3', '23_23', '38_48', '13_13', '15_20', '38_43', '38_42', '35_35'}
# 29

# %%
#(0-2, 4-6, 8-13, 15-20, 25-32, 38-43, 48-53, 60-)

# %%
id = {0: '0-2', 1: '4-6', 2: '8-13', 3: '15-20', 4: '25-32', 5: '38-43', 6: '48-53', 7: '60-'}

def group_age(x):

  if x in ['0_2', '2_2', '3_3']:
    return 0
  elif x in ['4_6']:
    return 1
  elif x in ['13_13', '8_12']:
    return 2
  elif x in ['8_23', '15_20', '22_22']:
    return 3
  elif x in ['34_34', '29_29', '23_23', '27_32', '25_32', '32_32']:
    return 4
  elif x in ['35_35', '42_42', '38_48', '36_36', '38_43', '38_42']:
    return 5
  elif x in ['48_53', '46_46', '45_45', '55_55', '56_56']:
    return 6
  elif x in ['58_58', '57_57', '60_100']:
    return 7
  else:
    raise RuntimeError("Unexpected Age Value")


grouped_age = list(map(group_age, age))

# %%
print(len(grouped_age))
print(set(grouped_age))
print(len(set(grouped_age)))
# Out:
# 17058
# {0, 1, 2, 3, 4, 5, 6, 7}
# 8

# %%
print(len(labels))
print(len(grouped_age))
# Out:
# 17058
# 17058

# %%
df = pd.DataFrame()

df["file"] = labels
df["age"] = grouped_age

# %%
del labels, age, grouped_age

# %%
df.head()
# Out:
#                                       file  age
# 0  98_11305749136_8542463c0e_o_48_53_1.jpg    6
# 1    97_11305704915_c5319b90c9_o_0_2_1.jpg    0
# 2    97_11285988483_9bec8b6362_o_0_2_1.jpg    0
# 3    97_11285942746_d4586bae2f_o_0_2_1.jpg    0
# 4  99_11309939424_20896ac2fd_o_25_32_0.jpg    4

# %%
ext = [i.split(".")[-1] for i in df['file']]
print(len(ext))
print(set(ext))
# Out:
# 17058
# {'jpg'}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17058 entries, 0 to 17057
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   file    17058 non-null  object
#  1   age     17058 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 266.7+ KB

# %%
import matplotlib.pyplot as plt

plt.hist(df.age, density=True, color='g')
plt.show()

# %%
df.age.value_counts().sort_index()
# Out:
# 0    2049
# 1    1921
# 2    2121
# 3    1574
# 4    5297
# 5    2447
# 6     882
# 7     767
# Name: age, dtype: int64

# %%
# !pip install -q tensorflow_addons

# %%
from tensorflow.keras.applications import EfficientNetB2
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization, Conv2D, GlobalAveragePooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow_addons.metrics import F1Score
from tensorflow.keras.metrics import Recall, Precision
import tensorflow as tf 
from tensorflow.keras import layers

# %%
IMG_SIZE = 128

from PIL import Image
from tensorflow.keras.utils import to_categorical

class DataGenerator():
    def __init__(self, df):
        self.df = df
        
    def generate_split_indexes(self):
        p = np.random.permutation(len(self.df))
        train_up_to = int(len(self.df) * 0.15)
        train_idx = p[:train_up_to]
        valid_idx = p[train_up_to:]
        
        return train_idx, valid_idx


    def norm(self, im):
        ma = np.max(im)
        mi = np.min(im)
        return (im - mi)/(ma - mi)
    
    def preprocess_image(self, img_path):
        """
        Used to perform some minor preprocessing on the image before inputting into the network.
        """
        im = Image.open('/content/drive/MyDrive/Adience_Processed/' + img_path)
        im = im.resize((IMG_SIZE, IMG_SIZE))
        return self.norm(im)
        
    def get_labels(self, image_idx):

        labels = []
        for idx in image_idx:
            person = self.df.iloc[idx]
            labels.append(to_categorical(person['age'], 8))
        return labels
    
    
    def generate_images(self, image_idx, is_training, batch_size=16):
      
        # arrays to store our batched data
        images, ages = [], []
        while 1:
            for idx in image_idx:
                person = self.df.iloc[idx]
                
                age = person['age']
                fil = person['file']
                
                im = self.preprocess_image(fil)
                
                ages.append(to_categorical(age, 8))
                images.append(im)
                
                # yielding condition
                if len(images) >= batch_size:
                    yield np.array(images), [np.array(ages)]
                    images, ages = [], []
                    
            if not is_training:
                break
                
data_generator = DataGenerator(df)
valid_idx, train_idx = data_generator.generate_split_indexes()

# %%
print(len(train_idx))
print(len(valid_idx))
# Out:
# 14500
# 2558

# %%
data_augmentation = tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal"),
  layers.experimental.preprocessing.RandomRotation(0.2),
  # layers.experimental.preprocessing.RandomZoom(-0.2, -0.2)
])

# %%
base_model = EfficientNetB2(include_top=False)
regularizer = l2(0.03)

for layer in base_model.layers:
    for attr in ['kernel_regularizer']:
        if hasattr(layer, attr):
          setattr(layer, attr, regularizer)

model = tf.keras.Sequential([
                             tf.keras.Input(shape = [IMG_SIZE, IMG_SIZE, 3]),
                            #  resize,
                             data_augmentation,
                             BatchNormalization(axis=3),
                             base_model,
                             GlobalAveragePooling2D(),
                             Dropout(0.45),
                             Dense(8, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 128, 128, 3)       0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 128, 3)       12
# _________________________________________________________________
# efficientnetb2 (Functional)  (None, None, None, 1408)  7768569
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1408)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1408)              0
# _________________________________________________________________
# dense (Dense)                (None, 8)                 11272
# =================================================================
# Total params: 7,779,853
# Trainable params: 7,712,272
# Non-trainable params: 67,581
# _________________________________________________________________

# %%
model.compile(
  loss='categorical_crossentropy',
  optimizer=tf.keras.optimizers.Adam(0.001, clipnorm=0.001),
  metrics=['categorical_accuracy', Recall(), Precision(), F1Score(8)]
)

# %%
Model_name = "Adience_B2"
batch_size = 128
epochs = 25

train_gen = data_generator.generate_images(train_idx, is_training=True, batch_size=batch_size)
val_gen = data_generator.generate_images(valid_idx, is_training=True, batch_size=batch_size)

def step(epoch, lr):
    return lr * tf.math.exp(-0.2)

callbacks = [
    ModelCheckpoint(f"/content/drive/MyDrive/Adience/{Model_name}.h5", monitor='categorical_accuracy', save_best_only=True, verbose=1),
    LearningRateScheduler(step, verbose=1),
    EarlyStopping(monitor = 'categorical_accuracy', patience = 7, verbose = 1)
]

history = model.fit(train_gen,
                    steps_per_epoch=50,
                    epochs=epochs,
                    callbacks=callbacks,
                    validation_steps = 20,
                    validation_data=val_gen)
# Out:
# Epoch 1/25
#
# Epoch 00001: LearningRateScheduler reducing learning rate to tf.Tensor(0.0008187308, shape=(), dtype=float32).
# 50/50 [==============================] - 758s 15s/step - loss: 1.8967 - categorical_accuracy: 0.2868 - recall: 0.0954 - precision: 0.5024 - f1_score: 0.2023 - val_loss: 2.3063 - val_categorical_accuracy: 0.1457 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_f1_score: 0.0318
#
# Epoch 00001: categorical_accuracy improved from -inf to 0.36812, saving model to /content/drive/MyDrive/Adience/Adience_B2.h5
# Epoch 2/25
#
# Epoch 00002: LearningRateScheduler reducing learning rate to tf.Tensor(0.0006703201, shape=(), dtype=float32).
# 50/50 [==============================] - 544s 11s/step - loss: 1.3432 - categorical_accuracy: 0.4761 - recall: 0.2797 - precision: 0.6327 - f1_score: 0.3968 - val_loss: 2.6194 - val_categorical_accuracy: 0.0449 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_f1_score: 0.0107
#
# Epoch 00002: categorical_accuracy improved from 0.36812 to 0.49812, saving model to /content/drive/MyDrive/Adience/Adience_B2.h5
# Epoch 3/25
#
# Epoch 00003: LearningRateScheduler reducing learning rate to tf.Tensor(0.0005488117, shape=(), dtype=float32).
# 50/50 [==============================] - 196s 4s/step - loss: 1.1479 - categorical_accuracy: 0.5390 - recall: 0.3802 - precision: 0.6650 - f1_score: 0.4849 - val_loss: 3.1638 - val_categorical_accuracy: 0.0449 - val_recall: 0.0422 - val_precision: 0.0456 - val_f1_score: 0.0107
#
# Epoch 00003: categorical_accuracy improved from 0.49812 to 0.56109, saving model to /content/drive/MyDrive/Adience/Adience_B2.h5
# Epoch 4/25
#
# Epoch 00004: LearningRateScheduler reducing learning rate to tf.Tensor(0.000449329, shape=(), dtype=float32).
# 50/50 [==============================] - 68s 1s/step - loss: 0.9889 - categorical_accuracy: 0.6198 - recall: 0.4947 - precision: 0.7221 - f1_score: 0.5645 - val_loss: 2.8268 - val_categorical_accuracy: 0.0449 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_f1_score: 0.0107
#
# Epoch 00004: categorical_accuracy improved from 0.56109 to 0.61937, saving model to /content/drive/MyDrive/Adience/Adience_B2.h5
# Epoch 5/25
#
# Epoch 00005: LearningRateScheduler reducing learning rate to tf.Tensor(0.0003678795, shape=(), dtype=float32).
# 50/50 [==============================] - 69s 1s/step - loss: 0.8794 - categorical_accuracy: 0.6594 - recall: 0.5552 - precision: 0.7424 - f1_score: 0.6128 - val_loss: 3.4265 - val_categorical_accuracy: 0.0449 - val_recall: 0.0398 - val_precision: 0.0457 - val_f1_score: 0.0110
#
# Epoch 00005: categorical_accuracy improved from 0.61937 to 0.66281, saving model to /content/drive/MyDrive/Adience/Adience_B2.h5
# Epoch 6/25
#
# Epoch 00006: LearningRateScheduler reducing learning rate to tf.Tensor(0.00030119426, shape=(), dtype=float32).
# 50/50 [==============================] - 68s 1s/step - loss: 0.7923 - categorical_accuracy: 0.6981 - recall: 0.6091 - precision: 0.7776 - f1_score: 0.6572 - val_loss: 3.1666 - val_categorical_accuracy: 0.0488 - val_recall: 0.0020 - val_precision: 0.1163 - val_f1_score: 0.0217
#
# Epoch 00006: categorical_accuracy improved from 0.66281 to 0.69797, saving model to /content/drive/MyDrive/Adience/Adience_B2.h5
# Epoch 7/25
#
# Epoch 00007: LearningRateScheduler reducing learning rate to tf.Tensor(0.00024659702, shape=(), dtype=float32).
# 50/50 [==============================] - 69s 1s/step - loss: 0.7455 - categorical_accuracy: 0.7162 - recall: 0.6285 - precision: 0.7823 - f1_score: 0.6914 - val_loss: 3.2847 - val_categorical_accuracy: 0.0477 - val_recall: 0.0254 - val_precision: 0.0781 - val_f1_score: 0.0182
#
# Epoch 00007: categorical_accuracy improved from 0.69797 to 0.72016, saving model to /content/drive/MyDrive/Adience/Adience_B2.h5
# Epoch 8/25
#
# Epoch 00008: LearningRateScheduler reducing learning rate to tf.Tensor(0.00020189656, shape=(), dtype=float32).
# 50/50 [==============================] - 69s 1s/step - loss: 0.6570 - categorical_accuracy: 0.7516 - recall: 0.6788 - precision: 0.8049 - f1_score: 0.7243 - val_loss: 2.2601 - val_categorical_accuracy: 0.1109 - val_recall: 0.0293 - val_precision: 0.5474 - val_f1_score: 0.0879
#
# Epoch 00008: categorical_accuracy improved from 0.72016 to 0.74922, saving model to /content/drive/MyDrive/Adience/Adience_B2.h5
# Epoch 9/25
#
# Epoch 00009: LearningRateScheduler reducing learning rate to tf.Tensor(0.00016529893, shape=(), dtype=float32).
# 50/50 [==============================] - 68s 1s/step - loss: 0.6336 - categorical_accuracy: 0.7557 - recall: 0.6891 - precision: 0.8140 - f1_score: 0.7268 - val_loss: 2.8187 - val_categorical_accuracy: 0.0703 - val_recall: 0.0238 - val_precision: 0.0938 - val_f1_score: 0.0501
#
# Epoch 00009: categorical_accuracy improved from 0.74922 to 0.76016, saving model to /content/drive/MyDrive/Adience/Adience_B2.h5
# Epoch 10/25
#
# Epoch 00010: LearningRateScheduler reducing learning rate to tf.Tensor(0.00013533531, shape=(), dtype=float32).
# 50/50 [==============================] - 68s 1s/step - loss: 0.5489 - categorical_accuracy: 0.7933 - recall: 0.7423 - precision: 0.8418 - f1_score: 0.7683 - val_loss: 1.9611 - val_categorical_accuracy: 0.2828 - val_recall: 0.1738 - val_precision: 0.4518 - val_f1_score: 0.2543
#
# Epoch 00010: categorical_accuracy improved from 0.76016 to 0.79109, saving model to /content/drive/MyDrive/Adience/Adience_B2.h5
# Epoch 11/25
#
# Epoch 00011: LearningRateScheduler reducing learning rate to tf.Tensor(0.00011080319, shape=(), dtype=float32).
# 50/50 [==============================] - 68s 1s/step - loss: 0.5357 - categorical_accuracy: 0.7947 - recall: 0.7491 - precision: 0.8461 - f1_score: 0.7690 - val_loss: 1.4280 - val_categorical_accuracy: 0.4676 - val_recall: 0.3578 - val_precision: 0.5654 - val_f1_score: 0.4094
#
# Epoch 00011: categorical_accuracy improved from 0.79109 to 0.79719, saving model to /content/drive/MyDrive/Adience/Adience_B2.h5
# Epoch 12/25
#
# Epoch 00012: LearningRateScheduler reducing learning rate to tf.Tensor(9.071798e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 68s 1s/step - loss: 0.5197 - categorical_accuracy: 0.8037 - recall: 0.7617 - precision: 0.8427 - f1_score: 0.7825 - val_loss: 1.6501 - val_categorical_accuracy: 0.4270 - val_recall: 0.3230 - val_precision: 0.5434 - val_f1_score: 0.3867
#
# Epoch 00012: categorical_accuracy improved from 0.79719 to 0.81078, saving model to /content/drive/MyDrive/Adience/Adience_B2.h5
# Epoch 13/25
#
# Epoch 00013: LearningRateScheduler reducing learning rate to tf.Tensor(7.42736e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 69s 1s/step - loss: 0.4929 - categorical_accuracy: 0.8165 - recall: 0.7692 - precision: 0.8537 - f1_score: 0.7936 - val_loss: 1.1790 - val_categorical_accuracy: 0.5629 - val_recall: 0.4457 - val_precision: 0.6645 - val_f1_score: 0.5186
#
# Epoch 00013: categorical_accuracy improved from 0.81078 to 0.82219, saving model to /content/drive/MyDrive/Adience/Adience_B2.h5
# Epoch 14/25
#
# Epoch 00014: LearningRateScheduler reducing learning rate to tf.Tensor(6.081008e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 69s 1s/step - loss: 0.4657 - categorical_accuracy: 0.8297 - recall: 0.7881 - precision: 0.8657 - f1_score: 0.8125 - val_loss: 0.9506 - val_categorical_accuracy: 0.6418 - val_recall: 0.5703 - val_precision: 0.7139 - val_f1_score: 0.6048
#
# Epoch 00014: categorical_accuracy improved from 0.82219 to 0.82844, saving model to /content/drive/MyDrive/Adience/Adience_B2.h5
# Epoch 15/25
#
# Epoch 00015: LearningRateScheduler reducing learning rate to tf.Tensor(4.9787086e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 68s 1s/step - loss: 0.4452 - categorical_accuracy: 0.8332 - recall: 0.7934 - precision: 0.8662 - f1_score: 0.8149 - val_loss: 0.7802 - val_categorical_accuracy: 0.7125 - val_recall: 0.6621 - val_precision: 0.7687 - val_f1_score: 0.6742
#
# Epoch 00015: categorical_accuracy improved from 0.82844 to 0.83594, saving model to /content/drive/MyDrive/Adience/Adience_B2.h5
# Epoch 16/25
#
# Epoch 00016: LearningRateScheduler reducing learning rate to tf.Tensor(4.076222e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 68s 1s/step - loss: 0.4317 - categorical_accuracy: 0.8358 - recall: 0.8007 - precision: 0.8724 - f1_score: 0.8210 - val_loss: 0.7357 - val_categorical_accuracy: 0.7320 - val_recall: 0.6973 - val_precision: 0.7785 - val_f1_score: 0.6973
#
# Epoch 00016: categorical_accuracy improved from 0.83594 to 0.84156, saving model to /content/drive/MyDrive/Adience/Adience_B2.h5
# Epoch 17/25
#
# Epoch 00017: LearningRateScheduler reducing learning rate to tf.Tensor(3.3373286e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 68s 1s/step - loss: 0.4329 - categorical_accuracy: 0.8390 - recall: 0.8094 - precision: 0.8740 - f1_score: 0.8222 - val_loss: 0.7325 - val_categorical_accuracy: 0.7387 - val_recall: 0.7031 - val_precision: 0.7725 - val_f1_score: 0.7027
#
# Epoch 00017: categorical_accuracy improved from 0.84156 to 0.84469, saving model to /content/drive/MyDrive/Adience/Adience_B2.h5
# Epoch 18/25
#
# Epoch 00018: LearningRateScheduler reducing learning rate to tf.Tensor(2.7323737e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 68s 1s/step - loss: 0.4143 - categorical_accuracy: 0.8428 - recall: 0.8102 - precision: 0.8798 - f1_score: 0.8231 - val_loss: 0.6852 - val_categorical_accuracy: 0.7574 - val_recall: 0.7254 - val_precision: 0.7912 - val_f1_score: 0.7288
#
# Epoch 00018: categorical_accuracy improved from 0.84469 to 0.84688, saving model to /content/drive/MyDrive/Adience/Adience_B2.h5
# Epoch 19/25
#
# Epoch 00019: LearningRateScheduler reducing learning rate to tf.Tensor(2.2370783e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 68s 1s/step - loss: 0.4082 - categorical_accuracy: 0.8520 - recall: 0.8231 - precision: 0.8831 - f1_score: 0.8244 - val_loss: 0.7436 - val_categorical_accuracy: 0.7453 - val_recall: 0.7102 - val_precision: 0.7710 - val_f1_score: 0.7060
#
# Epoch 00019: categorical_accuracy improved from 0.84688 to 0.85297, saving model to /content/drive/MyDrive/Adience/Adience_B2.h5
# Epoch 20/25
#
# Epoch 00020: LearningRateScheduler reducing learning rate to tf.Tensor(1.8315648e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 68s 1s/step - loss: 0.4069 - categorical_accuracy: 0.8501 - recall: 0.8176 - precision: 0.8823 - f1_score: 0.8285 - val_loss: 0.6397 - val_categorical_accuracy: 0.7723 - val_recall: 0.7461 - val_precision: 0.8093 - val_f1_score: 0.7423
#
# Epoch 00020: categorical_accuracy improved from 0.85297 to 0.85375, saving model to /content/drive/MyDrive/Adience/Adience_B2.h5
# Epoch 21/25
#
# Epoch 00021: LearningRateScheduler reducing learning rate to tf.Tensor(1.4995585e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 68s 1s/step - loss: 0.3724 - categorical_accuracy: 0.8612 - recall: 0.8303 - precision: 0.8942 - f1_score: 0.8452 - val_loss: 0.6317 - val_categorical_accuracy: 0.7805 - val_recall: 0.7563 - val_precision: 0.8111 - val_f1_score: 0.7494
#
# Epoch 00021: categorical_accuracy improved from 0.85375 to 0.85844, saving model to /content/drive/MyDrive/Adience/Adience_B2.h5
# Epoch 22/25
#
# Epoch 00022: LearningRateScheduler reducing learning rate to tf.Tensor(1.2277347e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 68s 1s/step - loss: 0.3803 - categorical_accuracy: 0.8621 - recall: 0.8316 - precision: 0.8908 - f1_score: 0.8499 - val_loss: 0.6263 - val_categorical_accuracy: 0.7844 - val_recall: 0.7609 - val_precision: 0.8140 - val_f1_score: 0.7502
#
# Epoch 00022: categorical_accuracy improved from 0.85844 to 0.85938, saving model to /content/drive/MyDrive/Adience/Adience_B2.h5
# Epoch 23/25
#
# Epoch 00023: LearningRateScheduler reducing learning rate to tf.Tensor(1.0051842e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 69s 1s/step - loss: 0.3717 - categorical_accuracy: 0.8718 - recall: 0.8373 - precision: 0.8972 - f1_score: 0.8527 - val_loss: 0.6333 - val_categorical_accuracy: 0.7809 - val_recall: 0.7598 - val_precision: 0.8121 - val_f1_score: 0.7505
#
# Epoch 00023: categorical_accuracy improved from 0.85938 to 0.86656, saving model to /content/drive/MyDrive/Adience/Adience_B2.h5
# Epoch 24/25
#
# Epoch 00024: LearningRateScheduler reducing learning rate to tf.Tensor(8.229752e-06, shape=(), dtype=float32).
# 50/50 [==============================] - 68s 1s/step - loss: 0.3728 - categorical_accuracy: 0.8635 - recall: 0.8382 - precision: 0.8887 - f1_score: 0.8465 - val_loss: 0.6336 - val_categorical_accuracy: 0.7816 - val_recall: 0.7555 - val_precision: 0.8106 - val_f1_score: 0.7498
#
# Epoch 00024: categorical_accuracy improved from 0.86656 to 0.86672, saving model to /content/drive/MyDrive/Adience/Adience_B2.h5
# Epoch 25/25
#
# Epoch 00025: LearningRateScheduler reducing learning rate to tf.Tensor(6.737951e-06, shape=(), dtype=float32).
# 50/50 [==============================] - 68s 1s/step - loss: 0.3807 - categorical_accuracy: 0.8593 - recall: 0.8298 - precision: 0.8878 - f1_score: 0.8420 - val_loss: 0.6308 - val_categorical_accuracy: 0.7828 - val_recall: 0.7578 - val_precision: 0.8107 - val_f1_score: 0.7520
#
# Epoch 00025: categorical_accuracy did not improve from 0.86672

# %%
loss, acc, recall, precision, f1_score = model.evaluate(train_gen, verbose=0, steps = len(train_idx)//batch_size)
print("\nTraining \t Loss: {:.3}  Accuracy: {:.3}%  Recall: {:.3}%  Precision: {:.3}%  F1_Score: {:.3}%".format(loss, acc*100, recall*100, precision*100, max(f1_score)*100))

loss, acc, recall, precision, f1_score = model.evaluate(val_gen, verbose=0, steps = len(valid_idx)//batch_size)
print("\nTesting \t Loss: {:.3}  Accuracy: {:.3}%  Recall: {:.3}%  Precision: {:.3}%  F1_Score: {:.3}%".format(loss, acc*100, recall*100, precision*100, max(f1_score)*100))
# Out:
# Training 	 Loss: 0.28  Accuracy: 89.9%  Recall: 88.0%  Precision: 92.3%  F1_Score: 97.3%
#
# Testing 	 Loss: 0.63  Accuracy: 78.3%  Recall: 75.9%  Precision: 81.1%  F1_Score: 92.1%

# %%
import matplotlib.pyplot as plt

epochs = list(range(25))

plt.figure(figsize=(20,12))
plt.subplot(2, 2, 1)
plt.plot(epochs, history.history['loss'], 'g', label='Training loss')
plt.plot(epochs, history.history['val_loss'], 'b', label='Testing loss')
plt.xlabel('Epochs', size=12)
plt.ylabel('Loss', size=12)
plt.title('Training and Testing loss', size=17)
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(epochs, history.history['categorical_accuracy'], 'g', label='Training Accuracy')
plt.plot(epochs, history.history['val_categorical_accuracy'], 'b', label='Testing Accuracy')
plt.xlabel('Epochs', size=12)
plt.ylabel('Accuracy', size=12)
plt.title('Training and Testing Accuracy', size=17)
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(epochs, history.history['recall'], 'g', label='Training Recall')
plt.plot(epochs, history.history['val_recall'], 'b', label='Testing Recall')
plt.xlabel('Epochs', size=12)
plt.ylabel('Recall', size=12)
plt.title('Training and Testing Recall', size=17)
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(epochs, history.history['precision'], 'g', label='Training Precision')
plt.plot(epochs, history.history['val_precision'], 'b', label='Testing Precision')
plt.xlabel('Epochs', size=12)
plt.ylabel('Precision', size=12)
plt.title('Training and Testing Precision', size=17)
plt.legend()

plt.suptitle('EfficientNet-B0', size = 20)
plt.show()

# %% [markdown]
# ### confusion matrix

# %%
batch_size = 256
train_gen = data_generator.generate_images(train_idx, is_training=False, batch_size=batch_size)
val_gen = data_generator.generate_images(valid_idx[:2560], is_training=False, batch_size=batch_size)

# %%
import tensorflow as tf
from tensorflow_addons.metrics import F1Score
from tensorflow.math import confusion_matrix

Model_name = "Adience_B2"
model = tf.keras.models.load_model(f'/content/drive/MyDrive/Adience/{Model_name}.h5', custom_objects={'f1_score':F1Score(8)})

# %%
y_true = data_generator.get_labels(valid_idx[:2304])

# %%
y_pred = model.predict(val_gen)
y_true = np.array(y_true)

# %%
temp_y_pred = np.argmax(y_pred, axis=1)
temp_y_true = np.argmax(y_true, axis=1)

print(temp_y_pred.shape)
print(temp_y_true.shape)
# Out:
# (2304,)
# (2304,)

# %%
confusion_matrix(temp_y_true, temp_y_pred)
# Out:
# <tf.Tensor: shape=(8, 8), dtype=int32, numpy=
# array([[252,  16,   0,   0,   2,   0,   0,   0],
#        [ 22, 223,  23,   3,   2,   0,   0,   0],
#        [  0,  18, 216,  19,  19,   2,   1,   0],
#        [  0,   1,  11, 117,  41,   9,   1,   2],
#        [  4,   6,  11,  40, 626,  55,   6,   1],
#        [  1,   0,   7,  12,  71, 238,  14,   6],
#        [  0,   0,   1,   0,   6,  15,  72,   7],
#        [  0,   1,   1,   1,   6,  10,  23,  63]], dtype=int32)>
