# %%
import os
import numpy as np
import pandas as pd

labels = [i for i in os.listdir('/content/drive/MyDrive/Adience_Processed')]
len(labels)
# Out:
# 17058

# %%
age = ['_'.join(i.split("_")[-3:-1]) for i in labels]
print(len(age))
print(set(age))
print(len(set(age)))
# Out:
# 17058
# {'13_13', '15_20', '55_55', '42_42', '2_2', '58_58', '22_22', '57_57', '60_100', '38_43', '8_12', '56_56', '0_2', '35_35', '46_46', '29_29', '32_32', '45_45', '23_23', '36_36', '4_6', '27_32', '34_34', '25_32', '3_3', '38_42', '38_48', '48_53', '8_23'}
# 29

# %%
#(0-2, 4-6, 8-13, 15-20, 25-32, 38-43, 48-53, 60-)

# %%
id = {0: '0-2', 1: '4-6', 2: '8-13', 3: '15-20', 4: '25-32', 5: '38-43', 6: '48-53', 7: '60-'}

def group_age(x):

  if x in ['0_2', '2_2', '3_3']:
    return 0
  elif x in ['4_6']:
    return 1
  elif x in ['13_13', '8_12']:
    return 2
  elif x in ['8_23', '15_20', '22_22']:
    return 3
  elif x in ['34_34', '29_29', '23_23', '27_32', '25_32', '32_32']:
    return 4
  elif x in ['35_35', '42_42', '38_48', '36_36', '38_43', '38_42']:
    return 5
  elif x in ['48_53', '46_46', '45_45', '55_55', '56_56']:
    return 6
  elif x in ['58_58', '57_57', '60_100']:
    return 7
  else:
    raise RuntimeError("Unexpected Age Value")


grouped_age = list(map(group_age, age))

# %%
print(len(grouped_age))
print(set(grouped_age))
print(len(set(grouped_age)))
# Out:
# 17058
# {0, 1, 2, 3, 4, 5, 6, 7}
# 8

# %%
print(len(labels))
print(len(grouped_age))
# Out:
# 17058
# 17058

# %%
df = pd.DataFrame()

df["file"] = labels
df["age"] = grouped_age

# %%
del labels, age, grouped_age

# %%
df.head()
# Out:
#                                       file  age
# 0  98_11305749136_8542463c0e_o_48_53_1.jpg    6
# 1    97_11305704915_c5319b90c9_o_0_2_1.jpg    0
# 2    97_11285988483_9bec8b6362_o_0_2_1.jpg    0
# 3    97_11285942746_d4586bae2f_o_0_2_1.jpg    0
# 4  99_11309939424_20896ac2fd_o_25_32_0.jpg    4

# %%
ext = [i.split(".")[-1] for i in df['file']]
print(len(ext))
print(set(ext))
# Out:
# 17058
# {'jpg'}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17058 entries, 0 to 17057
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   file    17058 non-null  object
#  1   age     17058 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 266.7+ KB

# %%
import matplotlib.pyplot as plt

plt.hist(df.age, density=True, color='g')
plt.show()

# %%
df.age.value_counts().sort_index()
# Out:
# 0    2049
# 1    1921
# 2    2121
# 3    1574
# 4    5297
# 5    2447
# 6     882
# 7     767
# Name: age, dtype: int64

# %%
# !pip install -q tensorflow_addons

# %%
from tensorflow.keras.applications import EfficientNetB3
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization, Conv2D, GlobalAveragePooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow_addons.metrics import F1Score
from tensorflow.keras.metrics import Recall, Precision
import tensorflow as tf 
from tensorflow.keras import layers

# %%
IMG_SIZE = 128

from PIL import Image
from tensorflow.keras.utils import to_categorical

class DataGenerator():
    def __init__(self, df):
        self.df = df
        
    def generate_split_indexes(self):
        p = np.random.permutation(len(self.df))
        train_up_to = int(len(self.df) * 0.15)
        train_idx = p[:train_up_to]
        valid_idx = p[train_up_to:]
        
        return train_idx, valid_idx


    def norm(self, im):
        ma = np.max(im)
        mi = np.min(im)
        return (im - mi)/(ma - mi)
    
    def preprocess_image(self, img_path):
        """
        Used to perform some minor preprocessing on the image before inputting into the network.
        """
        im = Image.open('/content/drive/MyDrive/Adience_Processed/' + img_path)
        im = im.resize((IMG_SIZE, IMG_SIZE))
        return self.norm(im)
        
    def get_labels(self, image_idx):

        labels = []
        for idx in image_idx:
            person = self.df.iloc[idx]
            labels.append(to_categorical(person['age'], 8))
        return labels
    
    
    def generate_images(self, image_idx, is_training, batch_size=16):
      
        # arrays to store our batched data
        images, ages = [], []
        while 1:
            for idx in image_idx:
                person = self.df.iloc[idx]
                
                age = person['age']
                fil = person['file']
                
                im = self.preprocess_image(fil)
                
                ages.append(to_categorical(age, 8))
                images.append(im)
                
                # yielding condition
                if len(images) >= batch_size:
                    yield np.array(images), [np.array(ages)]
                    images, ages = [], []
                    
            if not is_training:
                break
                
data_generator = DataGenerator(df)
valid_idx, train_idx = data_generator.generate_split_indexes()

# %%
print(len(train_idx))
print(len(valid_idx))
# Out:
# 14500
# 2558

# %%
data_augmentation = tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal"),
  layers.experimental.preprocessing.RandomRotation(0.2),
  # layers.experimental.preprocessing.RandomZoom(-0.2, -0.2)
])

# %%
base_model = EfficientNetB3(include_top=False)
regularizer = l2(0.03)

for layer in base_model.layers:
    for attr in ['kernel_regularizer']:
        if hasattr(layer, attr):
          setattr(layer, attr, regularizer)

model = tf.keras.Sequential([
                             tf.keras.Input(shape = [IMG_SIZE, IMG_SIZE, 3]),
                            #  resize,
                             data_augmentation,
                             BatchNormalization(axis=3),
                             base_model,
                             GlobalAveragePooling2D(),
                             Dropout(0.45),
                             Dense(8, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 128, 128, 3)       0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 128, 3)       12
# _________________________________________________________________
# efficientnetb3 (Functional)  (None, None, None, 1536)  10783535
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1536)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1536)              0
# _________________________________________________________________
# dense (Dense)                (None, 8)                 12296
# =================================================================
# Total params: 10,795,843
# Trainable params: 10,708,534
# Non-trainable params: 87,309
# _________________________________________________________________

# %%
model.compile(
  loss='categorical_crossentropy',
  optimizer=tf.keras.optimizers.Adam(0.001, clipnorm=0.001),
  metrics=['categorical_accuracy', Recall(), Precision(), F1Score(8)]
)

# %%
Model_name = "Adience_B3"
batch_size = 128
epochs = 25

train_gen = data_generator.generate_images(train_idx, is_training=True, batch_size=batch_size)
val_gen = data_generator.generate_images(valid_idx, is_training=True, batch_size=batch_size)

def step(epoch, lr):
    return lr * tf.math.exp(-0.2)

callbacks = [
    ModelCheckpoint(f"/content/drive/MyDrive/Adience/{Model_name}.h5", monitor='categorical_accuracy', save_best_only=True, verbose=1),
    LearningRateScheduler(step, verbose=1),
    EarlyStopping(monitor = 'categorical_accuracy', patience = 7, verbose = 1)
]

history = model.fit(train_gen,
                    steps_per_epoch=50,
                    epochs=epochs,
                    callbacks=callbacks,
                    validation_steps = 20,
                    validation_data=val_gen)
# Out:
# Epoch 1/25
#
# Epoch 00001: LearningRateScheduler reducing learning rate to tf.Tensor(0.0008187308, shape=(), dtype=float32).
# 50/50 [==============================] - 1502s 30s/step - loss: 1.9063 - categorical_accuracy: 0.3005 - recall: 0.0987 - precision: 0.4762 - f1_score: 0.2116 - val_loss: 2.0087 - val_categorical_accuracy: 0.3078 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_f1_score: 0.0588
#
# Epoch 00001: categorical_accuracy improved from -inf to 0.36922, saving model to /content/drive/MyDrive/Adience/Adience_B3.h5
# Epoch 2/25
#
# Epoch 00002: LearningRateScheduler reducing learning rate to tf.Tensor(0.0006703201, shape=(), dtype=float32).
# 50/50 [==============================] - 1052s 21s/step - loss: 1.2737 - categorical_accuracy: 0.4996 - recall: 0.3117 - precision: 0.6357 - f1_score: 0.4203 - val_loss: 2.0634 - val_categorical_accuracy: 0.3074 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_f1_score: 0.0588
#
# Epoch 00002: categorical_accuracy improved from 0.36922 to 0.51797, saving model to /content/drive/MyDrive/Adience/Adience_B3.h5
# Epoch 3/25
#
# Epoch 00003: LearningRateScheduler reducing learning rate to tf.Tensor(0.0005488117, shape=(), dtype=float32).
# 50/50 [==============================] - 296s 6s/step - loss: 1.1422 - categorical_accuracy: 0.5540 - recall: 0.4098 - precision: 0.6925 - f1_score: 0.4861 - val_loss: 2.0719 - val_categorical_accuracy: 0.1668 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_f1_score: 0.0586
#
# Epoch 00003: categorical_accuracy improved from 0.51797 to 0.56922, saving model to /content/drive/MyDrive/Adience/Adience_B3.h5
# Epoch 4/25
#
# Epoch 00004: LearningRateScheduler reducing learning rate to tf.Tensor(0.000449329, shape=(), dtype=float32).
# 50/50 [==============================] - 44s 895ms/step - loss: 1.0036 - categorical_accuracy: 0.6106 - recall: 0.4882 - precision: 0.7170 - f1_score: 0.5622 - val_loss: 1.9786 - val_categorical_accuracy: 0.3074 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_f1_score: 0.0588
#
# Epoch 00004: categorical_accuracy improved from 0.56922 to 0.63406, saving model to /content/drive/MyDrive/Adience/Adience_B3.h5
# Epoch 5/25
#
# Epoch 00005: LearningRateScheduler reducing learning rate to tf.Tensor(0.0003678795, shape=(), dtype=float32).
# 50/50 [==============================] - 45s 903ms/step - loss: 0.8597 - categorical_accuracy: 0.6616 - recall: 0.5561 - precision: 0.7488 - f1_score: 0.6116 - val_loss: 2.1280 - val_categorical_accuracy: 0.2664 - val_recall: 0.0023 - val_precision: 0.2500 - val_f1_score: 0.0744
#
# Epoch 00005: categorical_accuracy improved from 0.63406 to 0.66922, saving model to /content/drive/MyDrive/Adience/Adience_B3.h5
# Epoch 6/25
#
# Epoch 00006: LearningRateScheduler reducing learning rate to tf.Tensor(0.00030119426, shape=(), dtype=float32).
# 50/50 [==============================] - 44s 893ms/step - loss: 0.7748 - categorical_accuracy: 0.6998 - recall: 0.6236 - precision: 0.7670 - f1_score: 0.6593 - val_loss: 2.0722 - val_categorical_accuracy: 0.3059 - val_recall: 0.2402 - val_precision: 0.3280 - val_f1_score: 0.0586
#
# Epoch 00006: categorical_accuracy improved from 0.66922 to 0.71109, saving model to /content/drive/MyDrive/Adience/Adience_B3.h5
# Epoch 7/25
#
# Epoch 00007: LearningRateScheduler reducing learning rate to tf.Tensor(0.00024659702, shape=(), dtype=float32).
# 50/50 [==============================] - 45s 899ms/step - loss: 0.6850 - categorical_accuracy: 0.7344 - recall: 0.6715 - precision: 0.7952 - f1_score: 0.7023 - val_loss: 2.0245 - val_categorical_accuracy: 0.3039 - val_recall: 0.1031 - val_precision: 0.3455 - val_f1_score: 0.0682
#
# Epoch 00007: categorical_accuracy improved from 0.71109 to 0.73625, saving model to /content/drive/MyDrive/Adience/Adience_B3.h5
# Epoch 8/25
#
# Epoch 00008: LearningRateScheduler reducing learning rate to tf.Tensor(0.00020189656, shape=(), dtype=float32).
# 50/50 [==============================] - 44s 896ms/step - loss: 0.6264 - categorical_accuracy: 0.7662 - recall: 0.6985 - precision: 0.8161 - f1_score: 0.7356 - val_loss: 2.0048 - val_categorical_accuracy: 0.2992 - val_recall: 0.1273 - val_precision: 0.3296 - val_f1_score: 0.1404
#
# Epoch 00008: categorical_accuracy improved from 0.73625 to 0.77000, saving model to /content/drive/MyDrive/Adience/Adience_B3.h5
# Epoch 9/25
#
# Epoch 00009: LearningRateScheduler reducing learning rate to tf.Tensor(0.00016529893, shape=(), dtype=float32).
# 50/50 [==============================] - 45s 903ms/step - loss: 0.5390 - categorical_accuracy: 0.7970 - recall: 0.7542 - precision: 0.8400 - f1_score: 0.7765 - val_loss: 1.8052 - val_categorical_accuracy: 0.3305 - val_recall: 0.1574 - val_precision: 0.4554 - val_f1_score: 0.2333
#
# Epoch 00009: categorical_accuracy improved from 0.77000 to 0.79578, saving model to /content/drive/MyDrive/Adience/Adience_B3.h5
# Epoch 10/25
#
# Epoch 00010: LearningRateScheduler reducing learning rate to tf.Tensor(0.00013533531, shape=(), dtype=float32).
# 50/50 [==============================] - 44s 897ms/step - loss: 0.5329 - categorical_accuracy: 0.7996 - recall: 0.7558 - precision: 0.8416 - f1_score: 0.7762 - val_loss: 1.6692 - val_categorical_accuracy: 0.4004 - val_recall: 0.2426 - val_precision: 0.5188 - val_f1_score: 0.2872
#
# Epoch 00010: categorical_accuracy improved from 0.79578 to 0.80219, saving model to /content/drive/MyDrive/Adience/Adience_B3.h5
# Epoch 11/25
#
# Epoch 00011: LearningRateScheduler reducing learning rate to tf.Tensor(0.00011080319, shape=(), dtype=float32).
# 50/50 [==============================] - 45s 902ms/step - loss: 0.4850 - categorical_accuracy: 0.8275 - recall: 0.7894 - precision: 0.8694 - f1_score: 0.8029 - val_loss: 1.5327 - val_categorical_accuracy: 0.4449 - val_recall: 0.3371 - val_precision: 0.5272 - val_f1_score: 0.3570
#
# Epoch 00011: categorical_accuracy improved from 0.80219 to 0.83625, saving model to /content/drive/MyDrive/Adience/Adience_B3.h5
# Epoch 12/25
#
# Epoch 00012: LearningRateScheduler reducing learning rate to tf.Tensor(9.071798e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 45s 900ms/step - loss: 0.4903 - categorical_accuracy: 0.8207 - recall: 0.7826 - precision: 0.8678 - f1_score: 0.8021 - val_loss: 1.4662 - val_categorical_accuracy: 0.4949 - val_recall: 0.4344 - val_precision: 0.5594 - val_f1_score: 0.4047
#
# Epoch 00012: categorical_accuracy did not improve from 0.83625
# Epoch 13/25
#
# Epoch 00013: LearningRateScheduler reducing learning rate to tf.Tensor(7.42736e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 44s 886ms/step - loss: 0.4213 - categorical_accuracy: 0.8508 - recall: 0.8169 - precision: 0.8823 - f1_score: 0.8319 - val_loss: 1.2739 - val_categorical_accuracy: 0.5637 - val_recall: 0.5148 - val_precision: 0.6153 - val_f1_score: 0.4967
#
# Epoch 00013: categorical_accuracy improved from 0.83625 to 0.85703, saving model to /content/drive/MyDrive/Adience/Adience_B3.h5
# Epoch 14/25
#
# Epoch 00014: LearningRateScheduler reducing learning rate to tf.Tensor(6.081008e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 45s 904ms/step - loss: 0.3871 - categorical_accuracy: 0.8616 - recall: 0.8257 - precision: 0.8908 - f1_score: 0.8441 - val_loss: 0.9528 - val_categorical_accuracy: 0.6773 - val_recall: 0.6445 - val_precision: 0.7161 - val_f1_score: 0.6242
#
# Epoch 00014: categorical_accuracy improved from 0.85703 to 0.85844, saving model to /content/drive/MyDrive/Adience/Adience_B3.h5
# Epoch 15/25
#
# Epoch 00015: LearningRateScheduler reducing learning rate to tf.Tensor(4.9787086e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 45s 906ms/step - loss: 0.3941 - categorical_accuracy: 0.8527 - recall: 0.8299 - precision: 0.8854 - f1_score: 0.8308 - val_loss: 0.9026 - val_categorical_accuracy: 0.6941 - val_recall: 0.6566 - val_precision: 0.7299 - val_f1_score: 0.6376
#
# Epoch 00015: categorical_accuracy improved from 0.85844 to 0.86359, saving model to /content/drive/MyDrive/Adience/Adience_B3.h5
# Epoch 16/25
#
# Epoch 00016: LearningRateScheduler reducing learning rate to tf.Tensor(4.076222e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 45s 907ms/step - loss: 0.3231 - categorical_accuracy: 0.8811 - recall: 0.8560 - precision: 0.9083 - f1_score: 0.8640 - val_loss: 0.7353 - val_categorical_accuracy: 0.7516 - val_recall: 0.7277 - val_precision: 0.7788 - val_f1_score: 0.7013
#
# Epoch 00016: categorical_accuracy improved from 0.86359 to 0.87500, saving model to /content/drive/MyDrive/Adience/Adience_B3.h5
# Epoch 17/25
#
# Epoch 00017: LearningRateScheduler reducing learning rate to tf.Tensor(3.3373286e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 44s 897ms/step - loss: 0.3524 - categorical_accuracy: 0.8699 - recall: 0.8464 - precision: 0.8961 - f1_score: 0.8524 - val_loss: 0.7575 - val_categorical_accuracy: 0.7473 - val_recall: 0.7270 - val_precision: 0.7719 - val_f1_score: 0.7005
#
# Epoch 00017: categorical_accuracy did not improve from 0.87500
# Epoch 18/25
#
# Epoch 00018: LearningRateScheduler reducing learning rate to tf.Tensor(2.7323737e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 44s 896ms/step - loss: 0.3207 - categorical_accuracy: 0.8860 - recall: 0.8642 - precision: 0.9109 - f1_score: 0.8715 - val_loss: 0.6606 - val_categorical_accuracy: 0.7812 - val_recall: 0.7613 - val_precision: 0.8044 - val_f1_score: 0.7493
#
# Epoch 00018: categorical_accuracy improved from 0.87500 to 0.88375, saving model to /content/drive/MyDrive/Adience/Adience_B3.h5
# Epoch 19/25
#
# Epoch 00019: LearningRateScheduler reducing learning rate to tf.Tensor(2.2370783e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 44s 894ms/step - loss: 0.3585 - categorical_accuracy: 0.8625 - recall: 0.8417 - precision: 0.8884 - f1_score: 0.8391 - val_loss: 0.6288 - val_categorical_accuracy: 0.7891 - val_recall: 0.7691 - val_precision: 0.8153 - val_f1_score: 0.7566
#
# Epoch 00019: categorical_accuracy did not improve from 0.88375
# Epoch 20/25
#
# Epoch 00020: LearningRateScheduler reducing learning rate to tf.Tensor(1.8315648e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 44s 889ms/step - loss: 0.3052 - categorical_accuracy: 0.8897 - recall: 0.8686 - precision: 0.9158 - f1_score: 0.8777 - val_loss: 0.6040 - val_categorical_accuracy: 0.8039 - val_recall: 0.7828 - val_precision: 0.8237 - val_f1_score: 0.7725
#
# Epoch 00020: categorical_accuracy improved from 0.88375 to 0.89359, saving model to /content/drive/MyDrive/Adience/Adience_B3.h5
# Epoch 21/25
#
# Epoch 00021: LearningRateScheduler reducing learning rate to tf.Tensor(1.4995585e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 44s 897ms/step - loss: 0.3122 - categorical_accuracy: 0.8859 - recall: 0.8694 - precision: 0.9107 - f1_score: 0.8698 - val_loss: 0.6044 - val_categorical_accuracy: 0.8016 - val_recall: 0.7855 - val_precision: 0.8272 - val_f1_score: 0.7687
#
# Epoch 00021: categorical_accuracy did not improve from 0.89359
# Epoch 22/25
#
# Epoch 00022: LearningRateScheduler reducing learning rate to tf.Tensor(1.2277347e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 44s 891ms/step - loss: 0.3119 - categorical_accuracy: 0.8902 - recall: 0.8719 - precision: 0.9135 - f1_score: 0.8796 - val_loss: 0.5981 - val_categorical_accuracy: 0.8055 - val_recall: 0.7848 - val_precision: 0.8261 - val_f1_score: 0.7757
#
# Epoch 00022: categorical_accuracy improved from 0.89359 to 0.89750, saving model to /content/drive/MyDrive/Adience/Adience_B3.h5
# Epoch 23/25
#
# Epoch 00023: LearningRateScheduler reducing learning rate to tf.Tensor(1.0051842e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 45s 901ms/step - loss: 0.2909 - categorical_accuracy: 0.9038 - recall: 0.8838 - precision: 0.9284 - f1_score: 0.8917 - val_loss: 0.5999 - val_categorical_accuracy: 0.8043 - val_recall: 0.7852 - val_precision: 0.8248 - val_f1_score: 0.7738
#
# Epoch 00023: categorical_accuracy did not improve from 0.89750
# Epoch 24/25
#
# Epoch 00024: LearningRateScheduler reducing learning rate to tf.Tensor(8.229752e-06, shape=(), dtype=float32).
# 50/50 [==============================] - 44s 889ms/step - loss: 0.3064 - categorical_accuracy: 0.8853 - recall: 0.8632 - precision: 0.9070 - f1_score: 0.8725 - val_loss: 0.5944 - val_categorical_accuracy: 0.8035 - val_recall: 0.7832 - val_precision: 0.8197 - val_f1_score: 0.7726
#
# Epoch 00024: categorical_accuracy did not improve from 0.89750
# Epoch 25/25
#
# Epoch 00025: LearningRateScheduler reducing learning rate to tf.Tensor(6.737951e-06, shape=(), dtype=float32).
# 50/50 [==============================] - 44s 893ms/step - loss: 0.2885 - categorical_accuracy: 0.8958 - recall: 0.8781 - precision: 0.9190 - f1_score: 0.8812 - val_loss: 0.5994 - val_categorical_accuracy: 0.8004 - val_recall: 0.7848 - val_precision: 0.8230 - val_f1_score: 0.7685
#
# Epoch 00025: categorical_accuracy did not improve from 0.89750

# %%
loss, acc, recall, precision, f1_score = model.evaluate(train_gen, verbose=0, steps = len(train_idx)//batch_size)
print("\nTraining \t Loss: {:.3}  Accuracy: {:.3}%  Recall: {:.3}%  Precision: {:.3}%  F1_Score: {:.3}%".format(loss, acc*100, recall*100, precision*100, max(f1_score)*100))

loss, acc, recall, precision, f1_score = model.evaluate(val_gen, verbose=0, steps = len(valid_idx)//batch_size)
print("\nTesting \t Loss: {:.3}  Accuracy: {:.3}%  Recall: {:.3}%  Precision: {:.3}%  F1_Score: {:.3}%".format(loss, acc*100, recall*100, precision*100, max(f1_score)*100))
# Out:
# Training 	 Loss: 0.206  Accuracy: 93.0%  Recall: 91.4%  Precision: 94.5%  F1_Score: 98.2%
#
# Testing 	 Loss: 0.593  Accuracy: 80.3%  Recall: 78.7%  Precision: 82.5%  F1_Score: 94.1%

# %%
import matplotlib.pyplot as plt

epochs = list(range(25))

plt.figure(figsize=(20,12))
plt.subplot(2, 2, 1)
plt.plot(epochs, history.history['loss'], 'g', label='Training loss')
plt.plot(epochs, history.history['val_loss'], 'b', label='Testing loss')
plt.xlabel('Epochs', size=12)
plt.ylabel('Loss', size=12)
plt.title('Training and Testing loss', size=17)
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(epochs, history.history['categorical_accuracy'], 'g', label='Training Accuracy')
plt.plot(epochs, history.history['val_categorical_accuracy'], 'b', label='Testing Accuracy')
plt.xlabel('Epochs', size=12)
plt.ylabel('Accuracy', size=12)
plt.title('Training and Testing Accuracy', size=17)
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(epochs, history.history['recall'], 'g', label='Training Recall')
plt.plot(epochs, history.history['val_recall'], 'b', label='Testing Recall')
plt.xlabel('Epochs', size=12)
plt.ylabel('Recall', size=12)
plt.title('Training and Testing Recall', size=17)
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(epochs, history.history['precision'], 'g', label='Training Precision')
plt.plot(epochs, history.history['val_precision'], 'b', label='Testing Precision')
plt.xlabel('Epochs', size=12)
plt.ylabel('Precision', size=12)
plt.title('Training and Testing Precision', size=17)
plt.legend()

plt.suptitle('EfficientNet-B0', size = 20)
plt.show()

# %% [markdown]
# ### confusion matrix

# %%
batch_size = 256
train_gen = data_generator.generate_images(train_idx, is_training=False, batch_size=batch_size)
val_gen = data_generator.generate_images(valid_idx[:2560], is_training=False, batch_size=batch_size)

# %%
import tensorflow as tf
from tensorflow_addons.metrics import F1Score
from tensorflow.math import confusion_matrix

Model_name = "Adience_B3"
model = tf.keras.models.load_model(f'/content/drive/MyDrive/Adience/{Model_name}.h5', custom_objects={'f1_score':F1Score(8)})

# %%
y_true = data_generator.get_labels(valid_idx[:2304])

# %%
y_pred = model.predict(val_gen)
y_true = np.array(y_true)

# %%
temp_y_pred = np.argmax(y_pred, axis=1)
temp_y_true = np.argmax(y_true, axis=1)

print(temp_y_pred.shape)
print(temp_y_true.shape)
# Out:
# (2304,)
# (2304,)

# %%
confusion_matrix(temp_y_true, temp_y_pred)
# Out:
# <tf.Tensor: shape=(8, 8), dtype=int32, numpy=
# array([[272,  17,   0,   0,   0,   0,   0,   0],
#        [ 14, 230,  15,   1,   1,   0,   0,   0],
#        [  1,  25, 232,  18,  15,   2,   0,   0],
#        [  0,   2,  17, 151,  38,  11,   2,   0],
#        [  1,   2,   8,  37, 603,  47,   4,   0],
#        [  0,   1,   2,   7,  67, 243,   5,   6],
#        [  0,   0,   0,   5,   9,  25,  57,  16],
#        [  0,   1,   0,   0,   4,  13,  11,  66]], dtype=int32)>
