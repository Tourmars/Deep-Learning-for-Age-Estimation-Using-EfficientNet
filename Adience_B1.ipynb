# %%
import os
import numpy as np
import pandas as pd

labels = [i for i in os.listdir('/content/drive/MyDrive/Adience_Processed')]
len(labels)
# Out:
# 17058

# %%
age = ['_'.join(i.split("_")[-3:-1]) for i in labels]
print(len(age))
print(set(age))
print(len(set(age)))
# Out:
# 17058
# {'36_36', '35_35', '29_29', '0_2', '15_20', '57_57', '60_100', '56_56', '55_55', '2_2', '25_32', '8_12', '34_34', '4_6', '46_46', '48_53', '58_58', '3_3', '42_42', '13_13', '38_43', '38_48', '45_45', '8_23', '22_22', '38_42', '27_32', '23_23', '32_32'}
# 29

# %%
#(0-2, 4-6, 8-13, 15-20, 25-32, 38-43, 48-53, 60-)

# %%
id = {0: '0-2', 1: '4-6', 2: '8-13', 3: '15-20', 4: '25-32', 5: '38-43', 6: '48-53', 7: '60-'}

def group_age(x):

  if x in ['0_2', '2_2', '3_3']:
    return 0
  elif x in ['4_6']:
    return 1
  elif x in ['13_13', '8_12']:
    return 2
  elif x in ['8_23', '15_20', '22_22']:
    return 3
  elif x in ['34_34', '29_29', '23_23', '27_32', '25_32', '32_32']:
    return 4
  elif x in ['35_35', '42_42', '38_48', '36_36', '38_43', '38_42']:
    return 5
  elif x in ['48_53', '46_46', '45_45', '55_55', '56_56']:
    return 6
  elif x in ['58_58', '57_57', '60_100']:
    return 7
  else:
    raise RuntimeError("Unexpected Age Value")


grouped_age = list(map(group_age, age))

# %%
print(len(grouped_age))
print(set(grouped_age))
print(len(set(grouped_age)))
# Out:
# 17058
# {0, 1, 2, 3, 4, 5, 6, 7}
# 8

# %%
print(len(labels))
print(len(grouped_age))
# Out:
# 17058
# 17058

# %%
df = pd.DataFrame()

df["file"] = labels
df["age"] = grouped_age

# %%
del labels, age, grouped_age

# %%
df.head()
# Out:
#                                       file  age
# 0  98_11305749136_8542463c0e_o_48_53_1.jpg    6
# 1    97_11305704915_c5319b90c9_o_0_2_1.jpg    0
# 2    97_11285988483_9bec8b6362_o_0_2_1.jpg    0
# 3    97_11285942746_d4586bae2f_o_0_2_1.jpg    0
# 4  99_11309939424_20896ac2fd_o_25_32_0.jpg    4

# %%
ext = [i.split(".")[-1] for i in df['file']]
print(len(ext))
print(set(ext))
# Out:
# 17058
# {'jpg'}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17058 entries, 0 to 17057
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   file    17058 non-null  object
#  1   age     17058 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 266.7+ KB

# %%
import matplotlib.pyplot as plt

plt.hist(df.age, density=True, color='g')
plt.show()

# %%
df.age.value_counts().sort_index()
# Out:
# 0    2049
# 1    1921
# 2    2121
# 3    1574
# 4    5297
# 5    2447
# 6     882
# 7     767
# Name: age, dtype: int64

# %%
# !pip install -q tensorflow_addons

# %%
from tensorflow.keras.applications import EfficientNetB1
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization, Conv2D, GlobalAveragePooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow_addons.metrics import F1Score
from tensorflow.keras.metrics import Recall, Precision
import tensorflow as tf 
from tensorflow.keras import layers

# %%
IMG_SIZE = 128

from PIL import Image
from tensorflow.keras.utils import to_categorical

class DataGenerator():
    def __init__(self, df):
        self.df = df
        
    def generate_split_indexes(self):
        p = np.random.permutation(len(self.df))
        train_up_to = int(len(self.df) * 0.15)
        train_idx = p[:train_up_to]
        valid_idx = p[train_up_to:]
        
        return train_idx, valid_idx


    def norm(self, im):
        ma = np.max(im)
        mi = np.min(im)
        return (im - mi)/(ma - mi)
    
    def preprocess_image(self, img_path):
        """
        Used to perform some minor preprocessing on the image before inputting into the network.
        """
        im = Image.open('/content/drive/MyDrive/Adience_Processed/' + img_path)
        im = im.resize((IMG_SIZE, IMG_SIZE))
        return self.norm(im)
        
    def get_labels(self, image_idx):

        labels = []
        for idx in image_idx:
            person = self.df.iloc[idx]
            labels.append(to_categorical(person['age'], 8))
        return labels
    
    
    def generate_images(self, image_idx, is_training, batch_size=16):
      
        # arrays to store our batched data
        images, ages = [], []
        while 1:
            for idx in image_idx:
                person = self.df.iloc[idx]
                
                age = person['age']
                fil = person['file']
                
                im = self.preprocess_image(fil)
                
                ages.append(to_categorical(age, 8))
                images.append(im)
                
                # yielding condition
                if len(images) >= batch_size:
                    yield np.array(images), [np.array(ages)]
                    images, ages = [], []
                    
            if not is_training:
                break
                
data_generator = DataGenerator(df)
valid_idx, train_idx = data_generator.generate_split_indexes()

# %%
print(len(train_idx))
print(len(valid_idx))
# Out:
# 14500
# 2558

# %%
data_augmentation = tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal"),
  layers.experimental.preprocessing.RandomRotation(0.2),
  # layers.experimental.preprocessing.RandomZoom(-0.2, -0.2)
])

# %%
base_model = EfficientNetB1(include_top=False)
regularizer = l2(0.03)

for layer in base_model.layers:
    for attr in ['kernel_regularizer']:
        if hasattr(layer, attr):
          setattr(layer, attr, regularizer)

model = tf.keras.Sequential([
                             tf.keras.Input(shape = [IMG_SIZE, IMG_SIZE, 3]),
                            #  resize,
                             data_augmentation,
                             BatchNormalization(axis=3),
                             base_model,
                             GlobalAveragePooling2D(),
                             Dropout(0.45),
                             Dense(8, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 128, 128, 3)       0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 128, 3)       12
# _________________________________________________________________
# efficientnetb1 (Functional)  (None, None, None, 1280)  6575239
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 8)                 10248
# =================================================================
# Total params: 6,585,499
# Trainable params: 6,523,438
# Non-trainable params: 62,061
# _________________________________________________________________

# %%
model.compile(
  loss='categorical_crossentropy',
  optimizer=tf.keras.optimizers.Adam(0.001, clipnorm=0.001),
  metrics=['categorical_accuracy', Recall(), Precision(), F1Score(8)]
)

# %%
Model_name = "Adience_B1"
batch_size = 128
epochs = 25

train_gen = data_generator.generate_images(train_idx, is_training=True, batch_size=batch_size)
val_gen = data_generator.generate_images(valid_idx, is_training=True, batch_size=batch_size)

def step(epoch, lr):
    return lr * tf.math.exp(-0.2)

callbacks = [
    ModelCheckpoint(f"/content/drive/MyDrive/Adience/{Model_name}.h5", monitor='categorical_accuracy', save_best_only=True, verbose=1),
    LearningRateScheduler(step, verbose=1),
    EarlyStopping(monitor = 'categorical_accuracy', patience = 7, verbose = 1)
]

history = model.fit(train_gen,
                    steps_per_epoch=50,
                    epochs=epochs,
                    callbacks=callbacks,
                    validation_steps = 20,
                    validation_data=val_gen)
# Out:
# Epoch 1/25
#
# Epoch 00001: LearningRateScheduler reducing learning rate to tf.Tensor(0.0008187308, shape=(), dtype=float32).
# 50/50 [==============================] - 193s 3s/step - loss: 1.9741 - categorical_accuracy: 0.2545 - recall: 0.0647 - precision: 0.4208 - f1_score: 0.2044 - val_loss: 2.0526 - val_categorical_accuracy: 0.3254 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_f1_score: 0.0614
#
# Epoch 00001: categorical_accuracy improved from -inf to 0.33344, saving model to /content/drive/MyDrive/Adience/Adience_B1.h5
# Epoch 2/25
#
# Epoch 00002: LearningRateScheduler reducing learning rate to tf.Tensor(0.0006703201, shape=(), dtype=float32).
# 50/50 [==============================] - 135s 3s/step - loss: 1.3808 - categorical_accuracy: 0.4641 - recall: 0.2644 - precision: 0.6202 - f1_score: 0.3854 - val_loss: 2.2168 - val_categorical_accuracy: 0.0410 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_f1_score: 0.0098
#
# Epoch 00002: categorical_accuracy improved from 0.33344 to 0.49156, saving model to /content/drive/MyDrive/Adience/Adience_B1.h5
# Epoch 3/25
#
# Epoch 00003: LearningRateScheduler reducing learning rate to tf.Tensor(0.0005488117, shape=(), dtype=float32).
# 50/50 [==============================] - 68s 1s/step - loss: 1.1735 - categorical_accuracy: 0.5398 - recall: 0.3762 - precision: 0.6804 - f1_score: 0.4693 - val_loss: 2.3237 - val_categorical_accuracy: 0.0414 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_f1_score: 0.0108
#
# Epoch 00003: categorical_accuracy improved from 0.49156 to 0.54391, saving model to /content/drive/MyDrive/Adience/Adience_B1.h5
# Epoch 4/25
#
# Epoch 00004: LearningRateScheduler reducing learning rate to tf.Tensor(0.000449329, shape=(), dtype=float32).
# 50/50 [==============================] - 46s 927ms/step - loss: 1.0033 - categorical_accuracy: 0.6068 - recall: 0.4717 - precision: 0.7036 - f1_score: 0.5451 - val_loss: 2.3044 - val_categorical_accuracy: 0.0809 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_f1_score: 0.0323
#
# Epoch 00004: categorical_accuracy improved from 0.54391 to 0.61719, saving model to /content/drive/MyDrive/Adience/Adience_B1.h5
# Epoch 5/25
#
# Epoch 00005: LearningRateScheduler reducing learning rate to tf.Tensor(0.0003678795, shape=(), dtype=float32).
# 50/50 [==============================] - 46s 918ms/step - loss: 0.9606 - categorical_accuracy: 0.6275 - recall: 0.5203 - precision: 0.7265 - f1_score: 0.5709 - val_loss: 2.2638 - val_categorical_accuracy: 0.1090 - val_recall: 0.0141 - val_precision: 0.1115 - val_f1_score: 0.0579
#
# Epoch 00005: categorical_accuracy improved from 0.61719 to 0.63313, saving model to /content/drive/MyDrive/Adience/Adience_B1.h5
# Epoch 6/25
#
# Epoch 00006: LearningRateScheduler reducing learning rate to tf.Tensor(0.00030119426, shape=(), dtype=float32).
# 50/50 [==============================] - 46s 922ms/step - loss: 0.8408 - categorical_accuracy: 0.6717 - recall: 0.5640 - precision: 0.7634 - f1_score: 0.6344 - val_loss: 2.1239 - val_categorical_accuracy: 0.2082 - val_recall: 0.0031 - val_precision: 0.1194 - val_f1_score: 0.0798
#
# Epoch 00006: categorical_accuracy improved from 0.63313 to 0.67828, saving model to /content/drive/MyDrive/Adience/Adience_B1.h5
# Epoch 7/25
#
# Epoch 00007: LearningRateScheduler reducing learning rate to tf.Tensor(0.00024659702, shape=(), dtype=float32).
# 50/50 [==============================] - 46s 920ms/step - loss: 0.7743 - categorical_accuracy: 0.7095 - recall: 0.6205 - precision: 0.7798 - f1_score: 0.6690 - val_loss: 2.2363 - val_categorical_accuracy: 0.0973 - val_recall: 0.0000e+00 - val_precision: 0.0000e+00 - val_f1_score: 0.0742
#
# Epoch 00007: categorical_accuracy improved from 0.67828 to 0.70469, saving model to /content/drive/MyDrive/Adience/Adience_B1.h5
# Epoch 8/25
#
# Epoch 00008: LearningRateScheduler reducing learning rate to tf.Tensor(0.00020189656, shape=(), dtype=float32).
# 50/50 [==============================] - 45s 915ms/step - loss: 0.7202 - categorical_accuracy: 0.7244 - recall: 0.6351 - precision: 0.7926 - f1_score: 0.6928 - val_loss: 2.5594 - val_categorical_accuracy: 0.0586 - val_recall: 0.0051 - val_precision: 0.0710 - val_f1_score: 0.0478
#
# Epoch 00008: categorical_accuracy improved from 0.70469 to 0.72641, saving model to /content/drive/MyDrive/Adience/Adience_B1.h5
# Epoch 9/25
#
# Epoch 00009: LearningRateScheduler reducing learning rate to tf.Tensor(0.00016529893, shape=(), dtype=float32).
# 50/50 [==============================] - 46s 923ms/step - loss: 0.6545 - categorical_accuracy: 0.7510 - recall: 0.6832 - precision: 0.8154 - f1_score: 0.7108 - val_loss: 2.1433 - val_categorical_accuracy: 0.2031 - val_recall: 0.0437 - val_precision: 0.3052 - val_f1_score: 0.1602
#
# Epoch 00009: categorical_accuracy improved from 0.72641 to 0.74734, saving model to /content/drive/MyDrive/Adience/Adience_B1.h5
# Epoch 10/25
#
# Epoch 00010: LearningRateScheduler reducing learning rate to tf.Tensor(0.00013533531, shape=(), dtype=float32).
# 50/50 [==============================] - 46s 917ms/step - loss: 0.6352 - categorical_accuracy: 0.7656 - recall: 0.6946 - precision: 0.8254 - f1_score: 0.7344 - val_loss: 2.3154 - val_categorical_accuracy: 0.2172 - val_recall: 0.0996 - val_precision: 0.2241 - val_f1_score: 0.1366
#
# Epoch 00010: categorical_accuracy improved from 0.74734 to 0.76797, saving model to /content/drive/MyDrive/Adience/Adience_B1.h5
# Epoch 11/25
#
# Epoch 00011: LearningRateScheduler reducing learning rate to tf.Tensor(0.00011080319, shape=(), dtype=float32).
# 50/50 [==============================] - 46s 916ms/step - loss: 0.5815 - categorical_accuracy: 0.7900 - recall: 0.7325 - precision: 0.8411 - f1_score: 0.7578 - val_loss: 2.1610 - val_categorical_accuracy: 0.1801 - val_recall: 0.0691 - val_precision: 0.3391 - val_f1_score: 0.1187
#
# Epoch 00011: categorical_accuracy improved from 0.76797 to 0.78609, saving model to /content/drive/MyDrive/Adience/Adience_B1.h5
# Epoch 12/25
#
# Epoch 00012: LearningRateScheduler reducing learning rate to tf.Tensor(9.071798e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 46s 924ms/step - loss: 0.5973 - categorical_accuracy: 0.7757 - recall: 0.7254 - precision: 0.8279 - f1_score: 0.7493 - val_loss: 1.7379 - val_categorical_accuracy: 0.3359 - val_recall: 0.1855 - val_precision: 0.4933 - val_f1_score: 0.2426
#
# Epoch 00012: categorical_accuracy did not improve from 0.78609
# Epoch 13/25
#
# Epoch 00013: LearningRateScheduler reducing learning rate to tf.Tensor(7.42736e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 46s 919ms/step - loss: 0.5168 - categorical_accuracy: 0.8048 - recall: 0.7545 - precision: 0.8513 - f1_score: 0.7797 - val_loss: 1.1486 - val_categorical_accuracy: 0.5816 - val_recall: 0.5309 - val_precision: 0.6512 - val_f1_score: 0.4777
#
# Epoch 00013: categorical_accuracy improved from 0.78609 to 0.80703, saving model to /content/drive/MyDrive/Adience/Adience_B1.h5
# Epoch 14/25
#
# Epoch 00014: LearningRateScheduler reducing learning rate to tf.Tensor(6.081008e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 46s 927ms/step - loss: 0.5267 - categorical_accuracy: 0.8073 - recall: 0.7606 - precision: 0.8476 - f1_score: 0.7828 - val_loss: 0.8740 - val_categorical_accuracy: 0.6828 - val_recall: 0.6336 - val_precision: 0.7339 - val_f1_score: 0.6248
#
# Epoch 00014: categorical_accuracy improved from 0.80703 to 0.80844, saving model to /content/drive/MyDrive/Adience/Adience_B1.h5
# Epoch 15/25
#
# Epoch 00015: LearningRateScheduler reducing learning rate to tf.Tensor(4.9787086e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 46s 926ms/step - loss: 0.5067 - categorical_accuracy: 0.8185 - recall: 0.7710 - precision: 0.8575 - f1_score: 0.7994 - val_loss: 0.7088 - val_categorical_accuracy: 0.7273 - val_recall: 0.6930 - val_precision: 0.7770 - val_f1_score: 0.6896
#
# Epoch 00015: categorical_accuracy improved from 0.80844 to 0.82203, saving model to /content/drive/MyDrive/Adience/Adience_B1.h5
# Epoch 16/25
#
# Epoch 00016: LearningRateScheduler reducing learning rate to tf.Tensor(4.076222e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 46s 920ms/step - loss: 0.4693 - categorical_accuracy: 0.8244 - recall: 0.7786 - precision: 0.8662 - f1_score: 0.7955 - val_loss: 0.7558 - val_categorical_accuracy: 0.7180 - val_recall: 0.6777 - val_precision: 0.7640 - val_f1_score: 0.6795
#
# Epoch 00016: categorical_accuracy did not improve from 0.82203
# Epoch 17/25
#
# Epoch 00017: LearningRateScheduler reducing learning rate to tf.Tensor(3.3373286e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 45s 909ms/step - loss: 0.4705 - categorical_accuracy: 0.8268 - recall: 0.7823 - precision: 0.8703 - f1_score: 0.8067 - val_loss: 0.6898 - val_categorical_accuracy: 0.7492 - val_recall: 0.7117 - val_precision: 0.7860 - val_f1_score: 0.7064
#
# Epoch 00017: categorical_accuracy did not improve from 0.82203
# Epoch 18/25
#
# Epoch 00018: LearningRateScheduler reducing learning rate to tf.Tensor(2.7323737e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 45s 913ms/step - loss: 0.4464 - categorical_accuracy: 0.8316 - recall: 0.7936 - precision: 0.8747 - f1_score: 0.8079 - val_loss: 0.6624 - val_categorical_accuracy: 0.7566 - val_recall: 0.7250 - val_precision: 0.7942 - val_f1_score: 0.7210
#
# Epoch 00018: categorical_accuracy improved from 0.82203 to 0.82641, saving model to /content/drive/MyDrive/Adience/Adience_B1.h5
# Epoch 19/25
#
# Epoch 00019: LearningRateScheduler reducing learning rate to tf.Tensor(2.2370783e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 46s 917ms/step - loss: 0.4601 - categorical_accuracy: 0.8275 - recall: 0.7904 - precision: 0.8658 - f1_score: 0.8032 - val_loss: 0.7113 - val_categorical_accuracy: 0.7410 - val_recall: 0.7090 - val_precision: 0.7786 - val_f1_score: 0.7029
#
# Epoch 00019: categorical_accuracy improved from 0.82641 to 0.83406, saving model to /content/drive/MyDrive/Adience/Adience_B1.h5
# Epoch 20/25
#
# Epoch 00020: LearningRateScheduler reducing learning rate to tf.Tensor(1.8315648e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 46s 922ms/step - loss: 0.4557 - categorical_accuracy: 0.8350 - recall: 0.7996 - precision: 0.8732 - f1_score: 0.8036 - val_loss: 0.6384 - val_categorical_accuracy: 0.7703 - val_recall: 0.7418 - val_precision: 0.8067 - val_f1_score: 0.7343
#
# Epoch 00020: categorical_accuracy did not improve from 0.83406
# Epoch 21/25
#
# Epoch 00021: LearningRateScheduler reducing learning rate to tf.Tensor(1.4995585e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 46s 919ms/step - loss: 0.4530 - categorical_accuracy: 0.8310 - recall: 0.7946 - precision: 0.8675 - f1_score: 0.8020 - val_loss: 0.6403 - val_categorical_accuracy: 0.7652 - val_recall: 0.7355 - val_precision: 0.8030 - val_f1_score: 0.7313
#
# Epoch 00021: categorical_accuracy improved from 0.83406 to 0.83828, saving model to /content/drive/MyDrive/Adience/Adience_B1.h5
# Epoch 22/25
#
# Epoch 00022: LearningRateScheduler reducing learning rate to tf.Tensor(1.2277347e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 46s 922ms/step - loss: 0.4514 - categorical_accuracy: 0.8339 - recall: 0.7990 - precision: 0.8715 - f1_score: 0.8081 - val_loss: 0.6354 - val_categorical_accuracy: 0.7684 - val_recall: 0.7379 - val_precision: 0.8028 - val_f1_score: 0.7353
#
# Epoch 00022: categorical_accuracy did not improve from 0.83828
# Epoch 23/25
#
# Epoch 00023: LearningRateScheduler reducing learning rate to tf.Tensor(1.0051842e-05, shape=(), dtype=float32).
# 50/50 [==============================] - 45s 914ms/step - loss: 0.4191 - categorical_accuracy: 0.8428 - recall: 0.8062 - precision: 0.8832 - f1_score: 0.8217 - val_loss: 0.6358 - val_categorical_accuracy: 0.7680 - val_recall: 0.7391 - val_precision: 0.8017 - val_f1_score: 0.7357
#
# Epoch 00023: categorical_accuracy improved from 0.83828 to 0.83859, saving model to /content/drive/MyDrive/Adience/Adience_B1.h5
# Epoch 24/25
#
# Epoch 00024: LearningRateScheduler reducing learning rate to tf.Tensor(8.229752e-06, shape=(), dtype=float32).
# 50/50 [==============================] - 46s 920ms/step - loss: 0.4383 - categorical_accuracy: 0.8388 - recall: 0.8030 - precision: 0.8757 - f1_score: 0.8257 - val_loss: 0.6526 - val_categorical_accuracy: 0.7652 - val_recall: 0.7344 - val_precision: 0.7963 - val_f1_score: 0.7322
#
# Epoch 00024: categorical_accuracy improved from 0.83859 to 0.84188, saving model to /content/drive/MyDrive/Adience/Adience_B1.h5
# Epoch 25/25
#
# Epoch 00025: LearningRateScheduler reducing learning rate to tf.Tensor(6.737951e-06, shape=(), dtype=float32).
# 50/50 [==============================] - 46s 922ms/step - loss: 0.4359 - categorical_accuracy: 0.8413 - recall: 0.8041 - precision: 0.8762 - f1_score: 0.8204 - val_loss: 0.6306 - val_categorical_accuracy: 0.7742 - val_recall: 0.7434 - val_precision: 0.8060 - val_f1_score: 0.7405
#
# Epoch 00025: categorical_accuracy did not improve from 0.84188

# %%
loss, acc, recall, precision, f1_score = model.evaluate(train_gen, verbose=0, steps = len(train_idx)//batch_size)
print("\nTraining \t Loss: {:.3}  Accuracy: {:.3}%  Recall: {:.3}%  Precision: {:.3}%  F1_Score: {:.3}%".format(loss, acc*100, recall*100, precision*100, max(f1_score)*100))

loss, acc, recall, precision, f1_score = model.evaluate(val_gen, verbose=0, steps = len(valid_idx)//batch_size)
print("\nTesting \t Loss: {:.3}  Accuracy: {:.3}%  Recall: {:.3}%  Precision: {:.3}%  F1_Score: {:.3}%".format(loss, acc*100, recall*100, precision*100, max(f1_score)*100))
# Out:
# Training 	 Loss: 0.333  Accuracy: 88.3%  Recall: 85.7%  Precision: 91.0%  F1_Score: 96.6%
#
# Testing 	 Loss: 0.623  Accuracy: 77.7%  Recall: 74.5%  Precision: 80.9%  F1_Score: 92.6%

# %%
import matplotlib.pyplot as plt

epochs = list(range(25))

plt.figure(figsize=(20,12))
plt.subplot(2, 2, 1)
plt.plot(epochs, history.history['loss'], 'g', label='Training loss')
plt.plot(epochs, history.history['val_loss'], 'b', label='Testing loss')
plt.xlabel('Epochs', size=12)
plt.ylabel('Loss', size=12)
plt.title('Training and Testing loss', size=17)
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(epochs, history.history['categorical_accuracy'], 'g', label='Training Accuracy')
plt.plot(epochs, history.history['val_categorical_accuracy'], 'b', label='Testing Accuracy')
plt.xlabel('Epochs', size=12)
plt.ylabel('Accuracy', size=12)
plt.title('Training and Testing Accuracy', size=17)
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(epochs, history.history['recall'], 'g', label='Training Recall')
plt.plot(epochs, history.history['val_recall'], 'b', label='Testing Recall')
plt.xlabel('Epochs', size=12)
plt.ylabel('Recall', size=12)
plt.title('Training and Testing Recall', size=17)
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(epochs, history.history['precision'], 'g', label='Training Precision')
plt.plot(epochs, history.history['val_precision'], 'b', label='Testing Precision')
plt.xlabel('Epochs', size=12)
plt.ylabel('Precision', size=12)
plt.title('Training and Testing Precision', size=17)
plt.legend()

plt.suptitle('EfficientNet-B0', size = 20)
plt.show()

# %% [markdown]
# ### confusion matrix

# %%
batch_size = 256
train_gen = data_generator.generate_images(train_idx, is_training=False, batch_size=batch_size)
val_gen = data_generator.generate_images(valid_idx[:2560], is_training=False, batch_size=batch_size)

# %%
import tensorflow as tf
from tensorflow_addons.metrics import F1Score
from tensorflow.math import confusion_matrix

Model_name = "Adience_B1"
model = tf.keras.models.load_model(f'/content/drive/MyDrive/Adience/{Model_name}.h5', custom_objects={'f1_score':F1Score(8)})

# %%
y_true = data_generator.get_labels(valid_idx[:2304])

# %%
y_pred = model.predict(val_gen)
y_true = np.array(y_true)

# %%
temp_y_pred = np.argmax(y_pred, axis=1)
temp_y_true = np.argmax(y_true, axis=1)

print(temp_y_pred.shape)
print(temp_y_true.shape)
# Out:
# (2304,)
# (2304,)

# %%
confusion_matrix(temp_y_true, temp_y_pred)
# Out:
# <tf.Tensor: shape=(8, 8), dtype=int32, numpy=
# array([[274,   7,   0,   0,   1,   1,   0,   0],
#        [ 30, 195,  20,   1,   2,   0,   0,   0],
#        [  3,  19, 237,  18,  11,   5,   0,   2],
#        [  0,   4,  23, 166,  28,   9,   0,   0],
#        [  1,   3,  19,  60, 590,  66,   6,   5],
#        [  1,   1,   1,   7,  78, 201,   8,   2],
#        [  0,   0,   2,   3,   3,  26,  61,   7],
#        [  0,   0,   1,   3,   5,  23,  19,  46]], dtype=int32)>
